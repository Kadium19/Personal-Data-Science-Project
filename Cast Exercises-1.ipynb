# %%
import pandas as pd

# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\user'

# %%
cast = pd.read_csv('F:/DATA SCIENCE/Python/June 6th/cast.csv')
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4   NaN
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %% [markdown]
# ### How many movies are listed in the titles dataframe?

# %%
cast.title.count()
# Out:
# 1048575

# %%
cast.title.value_counts()
# Out:
# Around the World in Eighty Days                  383
# 7 cajas                                          191
# The Dark Knight Rises                            173
# The Ten Commandments                             167
# King Kong                                        158
#                                                 ...
# Velugu Needalu                                     1
# Hoyo                                               1
# Tres de corazones                                  1
# Defending Against Attack 'The Complete Guide'      1
# Tai ping tian guo                                  1
# Name: title, Length: 150894, dtype: int64

# %%
cast.title.nunique()
# Out:
# 150894

# %%
type(cast)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### What are the earliest two films listed in the titles dataframe?

# %%
cast[['year','title']].sort_values('year',ascending=True).head(3)
# Out:
#         year       title
# 464860  1894  Miss Jerry
# 555929  1894  Miss Jerry
# 600975  1905     Valsons

# %% [markdown]
# ### How many movies have the title "Hamlet"?

# %%
cast[cast['title'].str.contains('Hamlet')]
# Out:
#                                      title  year               name   type  \
# 1615                                Hamlet  1996         Riz Abbasi  actor
# 4250     Royal Shakespeare Company: Hamlet  2016   Hiran Abeysekera  actor
# 6421             Hamlet, Prince of Denmark  1997       Ernest Abuba  actor
# 7438                                Hamlet  1921   Fritz Achterberg  actor
# 11242                               Hamlet  2009       Hayden Adams  actor
# ...                                    ...   ...                ...    ...
# 1039896                Harry, Hamlet and I  2013  Philip J. Russell  actor
# 1041808                      Zombie Hamlet  2012    Gildart Jackson  actor
# 1041828                             Hamlet  1969     Gordon Jackson  actor
# 1042957                      Zombie Hamlet  2012    Ryan H. Jackson  actor
# 1044207                             Hamlet  1996       Derek Jacobi  actor
#
#                                  character     n
# ...

# %%
cast[cast['title'].str.contains('Hamlet')][['title','name']].sort_index()
# Out:
#                                      title               name
# 1615                                Hamlet         Riz Abbasi
# 4250     Royal Shakespeare Company: Hamlet   Hiran Abeysekera
# 6421             Hamlet, Prince of Denmark       Ernest Abuba
# 7438                                Hamlet   Fritz Achterberg
# 11242                               Hamlet       Hayden Adams
# ...                                    ...                ...
# 1039896                Harry, Hamlet and I  Philip J. Russell
# 1041808                      Zombie Hamlet    Gildart Jackson
# 1041828                             Hamlet     Gordon Jackson
# 1042957                      Zombie Hamlet    Ryan H. Jackson
# 1044207                             Hamlet       Derek Jacobi
#
# [312 rows x 2 columns]

# %%
cast[cast['title'].str.contains('Hamlet')].shape
# Out:
# (312, 6)

# %% [markdown]
# ### How many movies are titled "North by Northwest"?

# %%
cast[cast['title'].str.contains('North by Northwest')]
# Out:
#                       title  year               name   type  \
# 12151    North by Northwest  1959      Stanley Adams  actor
# 27852    North by Northwest  1959         Andy Albin  actor
# 54093    North by Northwest  1959       Don Anderson  actor
# 54307    North by Northwest  1959    Ernest Anderson  actor
# 92195    North by Northwest  1959  Malcolm Atterbury  actor
# 97833    North by Northwest  1959          Tol Avery  actor
# 109025   North by Northwest  1959         Sam Bagley  actor
# 114334   North by Northwest  1959        Frank Baker  actor
# 137656   North by Northwest  1959      Baynes Barron  actor
# 151717   North by Northwest  1959      Brandon Beach  actor
# 176030   North by Northwest  1959      John Beradino  actor
# 198496   North by Northwest  1959       Edward Binns  actor
# 222299   North by Northwest  1959    Stephen Bolster  actor
# 343701   North by Northwest  1959     Leo G. Carroll  actor
# 344204   North by Northwest  1959   Steve Carruthers  actor
# ...

# %% [markdown]
# ### When was the first movie titled "Hamlet" made?

# %%
cast[cast['title'].str.contains('Hamlet')].sort_values('year').head(5)
# Out:
#          title  year             name   type   character     n
# 954648  Hamlet  1911      Aage Hertel  actor    Claudius   2.0
# 132982  Hamlet  1913      J.H. Barnes  actor    Polonius   4.0
# 174961  Hamlet  1913  Grendon Bentley  actor  Fortinbras   7.0
# 447543  Hamlet  1913     S.A. Cookson  actor     Horatio   3.0
# 930908  Hamlet  1913     George Hayes  actor       Osric  10.0

# %% [markdown]
# ### List all of the "Treasure Island" movies from earliest to most recent.

# %%
cast[cast['title'].str.contains('Treasure Island')].sort_values('year')
# Out:
#                                          title  year                name  \
# 840745                         Treasure Island  1918           Joe Grant
# 339256                         Treasure Island  1918   Francis Carpenter
# 909157                         Treasure Island  1918        Edwin Harley
# 830114                         Treasure Island  1918      Charles Gorman
# 537825                         Treasure Island  1920        Sydney Deane
# ...                                        ...   ...                 ...
# 199140  National Theatre Live: Treasure Island  2015        Oliver Birch
# 511053  National Theatre Live: Treasure Island  2015      Arthur Darvill
# 448109  National Theatre Live: Treasure Island  2015       Daniel Coonan
# 712520  National Theatre Live: Treasure Island  2015  Nick (II) Fletcher
# 112778  National Theatre Live: Treasure Island  2015           Raj Bajaj
#
#          type                character     n
# 840745  actor  Undetermined child role   NaN
# ...

# %% [markdown]
# ### How many movies were made in the year 1950?

# %%
cast[cast.year==1950]
# Out:
#                              title  year            name   type  \
# 266               Palletoori Pilla  1950  Subba Rao A.V.  actor
# 429                   Hallin Janne  1950  Kosti Aaltonen  actor
# 430                   Hallin Janne  1950  Kosti Aaltonen  actor
# 1481     Fortunes of Captain Blood  1950  Abdullah Abbas  actor
# 1497          The Baron of Arizona  1950  Abdullah Abbas  actor
# ...                            ...   ...             ...    ...
# 1046679         The Asphalt Jungle  1950       Sam Jaffe  actor
# 1047478                  Dark City  1950     Dean Jagger  actor
# 1047512                     Sierra  1950     Dean Jagger  actor
# 1047937         Medan staden sover  1950      Adolf Jahr  actor
# 1047951          In a Lonely Place  1950    Jack Jahries  actor
#
#                          character    n
# 266                  Kampanna Dora  4.0
# 429                          Rosvo  NaN
# 430                        Vartija  NaN
# ...

# %%
cast[cast.year==1950].shape
# Out:
# (7389, 6)

# %% [markdown]
# ### How many movies were made in the year 1960?

# %%
cast[cast.year==1960]
# Out:
#                               title  year                      name   type  \
# 68                     De zaak M.P.  1960             Frans 't Hoen  actor
# 115             Thunder in Carolina  1960  2nd Marine Division Band  actor
# 133                        Noi duri  1960              5 Asternovas  actor
# 265      Sri Venkateswara Mahatmyam  1960        Subba Rao A.V. Jr.  actor
# 268      Sri Venkateswara Mahatmyam  1960            Subba Rao A.V.  actor
# ...                             ...   ...                       ...    ...
# 1047649              Hum Hindustani  1960          Gajanan Jagirdar  actor
# 1047842        Fabrik der Offiziere  1960             Reinhard Jahn  actor
# 1048239      Return of Mr. Superman  1960                 P. Jairaj  actor
# 1048240      Return of Mr. Superman  1960                 P. Jairaj  actor
# 1048549                  Tava laime  1960           Girts Jakovlevs  actor
#
#                                       character     n
# ...

# %%
cast[cast.year==1960].count()
# Out:
# title        5608
# year         5608
# name         5608
# type         5608
# character    5608
# n            3451
# dtype: int64

# %% [markdown]
# ### How many movies were made from 1950 through 1959?

# %%
#cast[cast.year>=1950 and cast.year<=1959]

# %%
boolean =[]
for n in cast.year:
    if n>=1950 and n<=1959:
        boolean.append(True)
    else:
        boolean.append(False)

# %%
boolean[0:5]
# Out:
# [False, False, False, False, False]

# %%
is_long=pd.Series(boolean)

# %%
is_long
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1048570    False
# 1048571    False
# 1048572     True
# 1048573    False
# 1048574    False
# Length: 1048575, dtype: bool

# %%
cast[is_long]
# Out:
#                               title  year                  name   type  \
# 67                  Fire Down Below  1957  'Stretch' Cox Troupe  actor
# 69               Dorp aan de rivier  1958         Frans 't Hoen  actor
# 111            Ci sposeremo a Capri  1956         Quartetto 2+2  actor
# 118                  Die Todesarena  1953      Die 3 Motorellos  actor
# 266                Palletoori Pilla  1950        Subba Rao A.V.  actor
# ...                             ...   ...                   ...    ...
# 1048242  Samarat Prithviraj Chauvan  1959             P. Jairaj  actor
# 1048323                 Pod sumnjom  1956         Bozo Jajcanin  actor
# 1048400                       Touha  1958             Jan Jakes  actor
# 1048567    Zwei Bayern in St. Pauli  1956   Bernhard Jakschatat  actor
# 1048572                      H-8...  1958      Stjepan Jaksevac  actor
#
#                                                  character     n
# ...

# %%
cast[is_long].sort_values('year')
# Out:
#                                      title  year                name   type  \
# 267177      Counterspy Meets Scotland Yard  1950          Don Brodie  actor
# 776227                       Gone to Earth  1950    John (V) Garrett  actor
# 776116                        The Big Lift  1950      Elbert Garrett  actor
# 409024             Beyond the Purple Hills  1950         Bobby Clack  actor
# 1018042         The Angel with the Trumpet  1950  Wilfrid Hyde-White  actor
# ...                                    ...   ...                 ...    ...
# 499246   Liebe verboten - Heiraten erlaubt  1959        Klaus Dahlen  actor
# 499356             Abschied von den Wolken  1959         Paul Dahlke  actor
# 499376             Die feuerrote Baronesse  1959         Paul Dahlke  actor
# 499385                   Drillinge an Bord  1959         Paul Dahlke  actor
# 533285                   Solomon and Sheba  1959      F?lix de Pom?s  actor
#
#                 character     n
# ...

# %% [markdown]
# ### In what years has a movie titled "Batman" been released?

# %%
a=cast[cast['title']=='Batman'][['title','year']]
a.year.unique()
# Out:
# array([1943, 1989], dtype=int64)

# %%
a.sort_values('year').head(1)
# Out:
#         title  year
# 95672  Batman  1943

# %%
a[a.sort_values('year').duplicated()]
# Out:
# <ipython-input-37-9e90f47eff26>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   a[a.sort_values('year').duplicated()]
#           title  year
# 96186    Batman  1943
# 114034   Batman  1989
# 119476   Batman  1989
# 149767   Batman  1989
# 199262   Batman  1989
# 211518   Batman  1989
# 258721   Batman  1943
# 287420   Batman  1943
# 379733   Batman  1989
# 387956   Batman  1943
# 449581   Batman  1989
# 468892   Batman  1989
# 470065   Batman  1989
# 477447   Batman  1943
# 477448   Batman  1943
# 490035   Batman  1943
# 492323   Batman  1989
# 499977   Batman  1989
# 575535   Batman  1943
# 592716   Batman  1943
# 596448   Batman  1989
# 612482   Batman  1943
# 618032   Batman  1989
# 633157   Batman  1989
# 670819   Batman  1989
# 706534   Batman  1943
# 713064   Batman  1943
# 735294   Batman  1943
# 746897   Batman  1943
# 772267   Batman  1943
# 779455   Batman  1989
# 808898   Batman  1943
# 830209   Batman  1989
# 832826   Batman  1989
# ...

# %%
a.apply(pd.value_counts)
# Out:
#         title  year
# 1943      NaN  22.0
# 1989      NaN  23.0
# Batman   45.0   NaN

# %% [markdown]
# ### How many roles were there in the movie "Inception"?

# %%
cast[cast['title']=='Inception'][['title','character']]
# Out:
#             title              character
# 94333   Inception          LAX Passenger
# 143138  Inception  Fischer's Jet Captain
# 176819  Inception               Browning
# 190249  Inception       Mombasan Gambler
# 250191  Inception         Bridge Sub Con
# 314663  Inception                  Miles
# 321091  Inception       Elderly Bald Man
# 361119  Inception          LAX Passenger
# 417982  Inception         Bridge Sub Con
# 428199  Inception            Bar Sub Con
# 498708  Inception         Bridge Sub Con
# 569504  Inception                   Cobb
# 659835  Inception        Italian Gambler
# 666157  Inception           Stock Broker
# 682511  Inception                  Extra
# 684215  Inception             Cab Driver
# 711192  Inception        Penrose Sub Con
# 779284  Inception    Immigration Officer
# 783405  Inception        James (3 years)
# 802478  Inception          Lobby Sub Con
# 803728  Inception               Old Cobb
# 806524  Inception         Bridge Sub Con
# ...

# %%
cast[cast['title']=='Inception']['character'].count()
# Out:
# 27

# %% [markdown]
# ### How many roles in the movie "Inception" are NOT ranked by an "n" value?

# %%
cast[cast['title']=='Inception'][['title','character','n']].fillna("0")
# Out:
#             title              character   n
# 94333   Inception          LAX Passenger   0
# 143138  Inception  Fischer's Jet Captain  44
# 176819  Inception               Browning   8
# 190249  Inception       Mombasan Gambler   0
# 250191  Inception         Bridge Sub Con  29
# 314663  Inception                  Miles  11
# 321091  Inception       Elderly Bald Man  20
# 361119  Inception          LAX Passenger   0
# 417982  Inception         Bridge Sub Con  26
# 428199  Inception            Bar Sub Con  34
# 498708  Inception         Bridge Sub Con  30
# 569504  Inception                   Cobb   1
# 659835  Inception        Italian Gambler   0
# 666157  Inception           Stock Broker   0
# 682511  Inception                  Extra   0
# 684215  Inception             Cab Driver  23
# 711192  Inception        Penrose Sub Con  32
# 779284  Inception    Immigration Officer  45
# 783405  Inception        James (3 years)  17
# 802478  Inception          Lobby Sub Con  40
# ...

# %%
a=cast[cast['title']=='Inception'][['title','character','n']].fillna(0)
a[a.n== 0]
# Out:
#             title         character    n
# 94333   Inception     LAX Passenger  0.0
# 190249  Inception  Mombasan Gambler  0.0
# 361119  Inception     LAX Passenger  0.0
# 659835  Inception   Italian Gambler  0.0
# 666157  Inception      Stock Broker  0.0
# 682511  Inception             Extra  0.0
# 806524  Inception    Bridge Sub Con  0.0
# 971196  Inception        Pedestrian  0.0

# %% [markdown]
# ### But how many roles in the movie "Inception" did receive an "n" value?

# %%
a=cast[cast['title']=='Inception'][['title','character','n']].fillna("Not Received")
a[a.n!='Not Received']
# Out:
#             title              character   n
# 143138  Inception  Fischer's Jet Captain  44
# 176819  Inception               Browning   8
# 250191  Inception         Bridge Sub Con  29
# 314663  Inception                  Miles  11
# 321091  Inception       Elderly Bald Man  20
# 417982  Inception         Bridge Sub Con  26
# 428199  Inception            Bar Sub Con  34
# 498708  Inception         Bridge Sub Con  30
# 569504  Inception                   Cobb   1
# 684215  Inception             Cab Driver  23
# 711192  Inception        Penrose Sub Con  32
# 779284  Inception    Immigration Officer  45
# 783405  Inception        James (3 years)  17
# 802478  Inception          Lobby Sub Con  40
# 803728  Inception               Old Cobb  50
# 829338  Inception                 Arthur   2
# 878274  Inception                   Nash  12
# 907468  Inception                  Eames   4
# 932903  Inception                 Lawyer  21

# %% [markdown]
# ### Display the cast of "North by Northwest" in their correct "n"-value order, ignoring roles that did not earn a numeric "n" value.

# %%
cast
# Out:
#                         title  year               name   type  \
# 0              Closet Monster  2015           Buffy #1  actor
# 1             Suuri illusioni  1985             Homo $  actor
# 2         Battle of the Sexes  2017            $hutter  actor
# 3        Secret in Their Eyes  2015            $hutter  actor
# 4                  Steve Jobs  2015            $hutter  actor
# ...                       ...   ...                ...    ...
# 1048570               Iza sna  2014  Matija Jaksekovic  actor
# 1048571    Snivaj, zlato moje  2005  Matija Jaksekovic  actor
# 1048572                H-8...  1958   Stjepan Jaksevac  actor
# 1048573            C.R.A.Z.Y.  2005       Nikita Jaksi  actor
# 1048574        Piccoli fuochi  1985        Dino Jaksic  actor
#
#                        character     n
# 0                        Buffy 4   NaN
# 1                         Guests  22.0
# 2                Bobby Riggs Fan  10.0
# 3                2002 Dodger Fan   NaN
# ...

# %%
North= cast[cast['title'].str.contains('North by Northwest')].fillna("Not Received")
North[North.n!='Not Received'].sort_values('n',ascending= False)
# Out:
#                      title  year               name   type  \
# 198496  North by Northwest  1959       Edward Binns  actor
# 447893  North by Northwest  1959    Philip Coolidge  actor
# 642085  North by Northwest  1959  Robert Ellenstein  actor
# 343701  North by Northwest  1959     Leo G. Carroll  actor
# 840374  North by Northwest  1959         Cary Grant  actor
#
#                  character   n
# 198496      Captain Junket  15
# 447893           Dr. Cross  13
# 642085               Licht  11
# 343701       The Professor   5
# 840374  Roger O. Thornhill   1

# %% [markdown]
# ### Display the entire cast, in "n"-order, of the 1972 film "Sleuth".

# %%
cast[cast['title'].str.contains('Sleuth')][cast.year==1972]
# Out:
# <ipython-input-46-168fd56bc58d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cast[cast['title'].str.contains('Sleuth')][cast.year==1972]
#          title  year            name   type          character    n
# 314691  Sleuth  1972   Michael Caine  actor        Milo Tindle  2.0
# 360365  Sleuth  1972  Alec Cawthorne  actor  Inspector Doppler  3.0

# %% [markdown]
# ### Now display the entire cast, in "n"-order, of the 2007 version of "Sleuth".

# %%
sleuth=cast[cast['title'].str.contains('Sleuth')][cast.year==2007].fillna("Not Receeived")
sleuth[sleuth.n!='Not Receeived']
# Out:
# <ipython-input-47-64ac2daec801>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sleuth=cast[cast['title'].str.contains('Sleuth')][cast.year==2007].fillna("Not Receeived")
#          title  year           name   type character  n
# 314692  Sleuth  2007  Michael Caine  actor    Andrew  1

# %% [markdown]
# ### How many roles were credited in the silent 1921 version of Hamlet?

# %%
cast[cast['title']=='Hamlet'][cast.year==1921][['year','title','character']]
# Out:
# <ipython-input-48-40a28df8a58c>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cast[cast['title']=='Hamlet'][cast.year==1921][['year','title','character']]
#         year   title     character
# 7438    1921  Hamlet   Fortinbras,
# 442224  1921  Hamlet  K?nig Hamlet
# 535307  1921  Hamlet       Laertes

# %% [markdown]
# ### How many roles were credited in Branagh’s 1996 Hamlet?

# %%
cast[cast['title']=='Hamlet'][cast.year==1996][['year','title','character']]
# Out:
# <ipython-input-49-021508726ecf>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cast[cast['title']=='Hamlet'][cast.year==1996][['year','title','character']]
#          year   title                 character
# 1615     1996  Hamlet     Attendant to Claudius
# 92106    1996  Hamlet        English Ambassador
# 152349   1996  Hamlet        Second Gravedigger
# 206181   1996  Hamlet     Attendant to Claudius
# 211111   1996  Hamlet  Ghost of Hamlet's Father
# 241315   1996  Hamlet             Cadet in Play
# 250281   1996  Hamlet                    Hamlet
# 262368   1996  Hamlet                  Polonius
# 283598   1996  Hamlet                    Priest
# 307699   1996  Hamlet     Attendant to Claudius
# 331657   1996  Hamlet               Laertes Mob
# 482982   1996  Hamlet         First Gravedigger
# 500005   1996  Hamlet             Stage Manager
# 555725   1996  Hamlet                  Reynaldo
# 577284   1996  Hamlet              Guildenstern
# ...

# %% [markdown]
# ### How many "Hamlet" roles have been listed in all film credits through history?

# %%
cast[cast['title']=='Hamlet'].count()
# Out:
# title        113
# year         113
# name         113
# type         113
# character    113
# n             83
# dtype: int64

# %% [markdown]
# ### How many people have played an "Ophelia"?

# %%
cast[cast['character']=='Ophelia']
# Out:
#                                   title  year             name   type  \
# 238855       The Merry Maids of Madness  2016      Amy Bourque  actor
# 395196                   Jake Gets Paid  2009   Josie Chisholm  actor
# 453835                       Inoperable  2016  Crystal Cordero  actor
# 835461  Dogg's Hamlet, Cahoot's Macbeth  2005    Lucas Grabeel  actor
#
#        character     n
# 238855   Ophelia  11.0
# 395196   Ophelia   NaN
# 453835   Ophelia   NaN
# 835461   Ophelia   NaN

# %% [markdown]
# ### How many people have played a role called "The Dude"?

# %%
cast[cast['title'].str.contains("The Dude")][['title','character']]
# Out:
#                       title                 character
# 25522    The Dude Goes West       Wagonwheel Mechanic
# 27088    The Dude Goes West               Daniel Bone
# 32690       The Dude Ranger             Grocery Clerk
# 90201       The Dude Bandit                 Al Burton
# 115472      The Dude Ranger                  Townsman
# 163533      The Dude Bandit                      Hank
# 163534      The Dude Ranger               Party Guest
# 211301      The Dude Cowboy              Shorty O'Day
# 264134      The Dude Bandit                  Henchman
# 264135      The Dude Ranger             Bank Customer
# 283980   The Dude Goes West                     Smith
# 287294      The Dude Bandit               Posse Rider
# 287655      The Dude Bandit               Posse Rider
# 287656   The Dude Goes West                    Barfly
# 297884      The Dude Bandit               Sheriff Jim
# 302963    The Dude Wrangler                     Canby
# ...

# %%
cast[cast['title'].str.contains("The Dude")][['title','character']].count()
# Out:
# title        43
# character    43
# dtype: int64

# %% [markdown]
# ### How many people have played a role called "The Stranger"?

# %%
cast[cast['character'].str.contains("The Stranger")]
# Out:
#                               title  year                       name   type  \
# 24819                         Theeb  2014  Hassan Mutlag Al-Maraiyeh  actor
# 34302                My Time to Die  2014       Vincent H. Alexander  actor
# 64774                      Get Mean  1975               Tony Anthony  actor
# 64777      Lo straniero di silenzio  1968               Tony Anthony  actor
# 64779        Un dollaro tra i denti  1967               Tony Anthony  actor
# ...                             ...   ...                        ...    ...
# 959143                    Koreatown  2007                  Dan Hicks  actor
# 965335    Vado... l'ammazzo e torno  1967              George Hilton  actor
# 991383   Tales of an Ancient Empire  2010                Lee Horsley  actor
# 997859             Don't Look Back!  2003              Kevin Howarth  actor
# 1037161        Vaarallista vapautta  1962              Jussi Itkonen  actor
#
#                                 character    n
# ...

# %%
cast[cast['character'].str.contains("The Stranger")].shape
# Out:
# (91, 6)

# %% [markdown]
# ### How many roles has Sidney Poitier played throughout his career?

# %%
cast[cast['character'].str.contains('Sidney Poitier')]
# Out:
#                       title  year           name   type       character   n
# 346262  Brando Unauthorized  2011  Keenan Carter  actor  Sidney Poitier NaN

# %% [markdown]
# ### How many roles has Judi Dench played?

# %%
cast[cast['name'].str.contains('Judi Dench')]
# Out:
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []

# %% [markdown]
# ### List the supporting roles (having n=2) played by Cary Grant in the 1940s, in order by year.

# %%
Cary=cast[cast['name'].str.contains('Cary Grant')][cast['year']==1940]
# Out:
# <ipython-input-121-cfd20015666d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Cary=cast[cast['name'].str.contains('Cary Grant')][cast['year']==1940]

# %%
Cary[Cary.n ==2]
# Out:
#                    title  year        name   type character    n
# 840371  My Favorite Wife  1940  Cary Grant  actor      Nick  2.0

# %% [markdown]
# ### List the leading roles that Cary Grant played in the 1940s in order by year.

# %%
Cary=cast[cast['name'].str.contains('Cary Grant')][cast['year']==1940]
# Out:
# <ipython-input-123-cfd20015666d>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   Cary=cast[cast['name'].str.contains('Cary Grant')][cast['year']==1940]

# %%
Cary
# Out:
#                           title  year        name   type           character  \
# 840353          His Girl Friday  1940  Cary Grant  actor        Walter Burns
# 840371         My Favorite Wife  1940  Cary Grant  actor                Nick
# 840397  The Howards of Virginia  1940  Cary Grant  actor         Matt Howard
# 840399   The Philadelphia Story  1940  Cary Grant  actor  C. K. Dexter Haven
#
#           n
# 840353  1.0
# 840371  2.0
# 840397  1.0
# 840399  1.0

# %% [markdown]
# ### How many roles were available for actors in the 1950s?

# %%
cast[cast['year']==1950]
# Out:
#                              title  year            name   type  \
# 266               Palletoori Pilla  1950  Subba Rao A.V.  actor
# 429                   Hallin Janne  1950  Kosti Aaltonen  actor
# 430                   Hallin Janne  1950  Kosti Aaltonen  actor
# 1481     Fortunes of Captain Blood  1950  Abdullah Abbas  actor
# 1497          The Baron of Arizona  1950  Abdullah Abbas  actor
# ...                            ...   ...             ...    ...
# 1046679         The Asphalt Jungle  1950       Sam Jaffe  actor
# 1047478                  Dark City  1950     Dean Jagger  actor
# 1047512                     Sierra  1950     Dean Jagger  actor
# 1047937         Medan staden sover  1950      Adolf Jahr  actor
# 1047951          In a Lonely Place  1950    Jack Jahries  actor
#
#                          character    n
# 266                  Kampanna Dora  4.0
# 429                          Rosvo  NaN
# 430                        Vartija  NaN
# ...

# %%
cast[cast['year']==1950][cast['type']=='actor']
# Out:
# <ipython-input-144-3d63735563dd>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cast[cast['year']==1950][cast['type']=='actor']
#                              title  year            name   type  \
# 266               Palletoori Pilla  1950  Subba Rao A.V.  actor
# 429                   Hallin Janne  1950  Kosti Aaltonen  actor
# 430                   Hallin Janne  1950  Kosti Aaltonen  actor
# 1481     Fortunes of Captain Blood  1950  Abdullah Abbas  actor
# 1497          The Baron of Arizona  1950  Abdullah Abbas  actor
# ...                            ...   ...             ...    ...
# 1046679         The Asphalt Jungle  1950       Sam Jaffe  actor
# 1047478                  Dark City  1950     Dean Jagger  actor
# 1047512                     Sierra  1950     Dean Jagger  actor
# 1047937         Medan staden sover  1950      Adolf Jahr  actor
# 1047951          In a Lonely Place  1950    Jack Jahries  actor
#
# ...

# %% [markdown]
# ### How many roles were available for actresses in the 1950s?

# %%
cast[cast['year']==1950][cast['type']=='actresses']
# Out:
# <ipython-input-145-8aa11c5052f8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cast[cast['year']==1950][cast['type']=='actresses']
# Empty DataFrame
# Columns: [title, year, name, type, character, n]
# Index: []

# %% [markdown]
# ### How many leading roles (n=1) were available from the beginning of film history through 1980?

# %%
cast
# Out:
#                         title  year               name   type  \
# 0              Closet Monster  2015           Buffy #1  actor
# 1             Suuri illusioni  1985             Homo $  actor
# 2         Battle of the Sexes  2017            $hutter  actor
# 3        Secret in Their Eyes  2015            $hutter  actor
# 4                  Steve Jobs  2015            $hutter  actor
# ...                       ...   ...                ...    ...
# 1048570               Iza sna  2014  Matija Jaksekovic  actor
# 1048571    Snivaj, zlato moje  2005  Matija Jaksekovic  actor
# 1048572                H-8...  1958   Stjepan Jaksevac  actor
# 1048573            C.R.A.Z.Y.  2005       Nikita Jaksi  actor
# 1048574        Piccoli fuochi  1985        Dino Jaksic  actor
#
#                        character     n
# 0                        Buffy 4   NaN
# 1                         Guests  22.0
# 2                Bobby Riggs Fan  10.0
# 3                2002 Dodger Fan   NaN
# ...

# %%
cast[cast.year<=1980].sort_values('year',ascending=True)[cast.n==1][['year','character','n']]
# Out:
# <ipython-input-171-66e264c083b9>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cast[cast.year<=1980].sort_values('year',ascending=True)[cast.n==1][['year','character','n']]
#         year             character    n
# 766513  1906               Himself  1.0
# 789493  1907              Warrigal  1.0
# 148472  1908  The Wizard of Oz Man  1.0
# 918685  1909                 Moses  1.0
# 781486  1911           Frank Keane  1.0
# ...      ...                   ...  ...
# 91788   1980       Torajiro Kuruma  1.0
# 97497   1980                 Earle  1.0
# 501691  1980            Joe Brezzi  1.0
# 502383  1980          John McVicar  1.0
# 773259  1980           Alex Linden  1.0
#
# [18968 rows x 3 columns]

# %%
cast[cast.year<=1980].sort_values('year',ascending=True)[cast.n==1]['character'].count()
# Out:
# <ipython-input-175-19a6e38ae35a>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cast[cast.year<=1980].sort_values('year',ascending=True)[cast.n==1]['character'].count()
# 18968

# %% [markdown]
# ### How many non-leading roles were available through from the beginning of film history through 1980?

# %% [markdown]
# ### How many roles through 1980 were minor enough that they did not warrant a numeric "n" rank?

# %%
rank=cast[cast['year']==1980].fillna("Not Ranked")
rank[rank.n=='Not Ranked']
# Out:
#                                                     title  year  \
# 472      Bob Hope's All-Star Look at TV's Prime Time Wars  1980
# 998                                                Afanti  1980
# 1858                                                Faust  1980
# 4263                                            Baddegama  1980
# 4389                                              Usia 18  1980
# ...                                                   ...   ...
# 1048008                                           El nido  1980
# 1048084                                     The Naxalites  1980
# 1048156                                           Jazbaat  1980
# 1048162                                       Manokaamnaa  1980
# 1048182                                 The Burning Train  1980
#
#                      name   type          character           n
# 472          Willie Aames  actor            Himself  Not Ranked
# 998                 Abake  actor  Master Abu Laboke  Not Ranked
# ...

# %%
rank[rank.n=='Not Ranked'].count()
# Out:
# title        1209
# year         1209
# name         1209
# type         1209
# character    1209
# n            1209
# dtype: int64
